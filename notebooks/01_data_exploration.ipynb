# %% [markdown]
# <a href="https://colab.research.google.com/github/hibadash/-Breast-Ultrasound-Classification-Using-Xception-CNN-BUSI-Dataset/blob/main/notebooks/01_data_exploration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Notebook 01 — Exploration et Prétraitement des données

# %%
# Cloner le repo GitHub dans un dossier local "breast_project" (Vérification chaque fois mais c'est rapide)
import os
# Vérifie si le dossier "breast_project" existe, sinon clone dedans
if not os.path.exists("breast_project"):
    # !git clone https://github.com/hibadash/-Breast-Ultrasound-Classification-Using-Xception-CNN-BUSI-Dataset.git breast_project
# Aller dans le dossier cloné
# %cd breast_project
# Vérifier le contenu du projet
# !ls
# Out:
# Cloning into 'breast_project'...
# remote: Enumerating objects: 1632, done.
# remote: Counting objects: 100% (48/48), done.
# remote: Compressing objects: 100% (45/45), done.
# remote: Total 1632 (delta 22), reused 14 (delta 1), pack-reused 1584 (from 2)
# Receiving objects: 100% (1632/1632), 194.53 MiB | 25.63 MiB/s, done.
# Resolving deltas: 100% (134/134), done.
# Updating files: 100% (1589/1589), done.
# /content/breast_project
# app  data  notebooks  README.md  requirements.txt  results  src

# %%
from data.preprocess import say_hello
say_hello("Kawtar")
# Out:
# 'Hello Kawtar, preprocessing is ready!'
